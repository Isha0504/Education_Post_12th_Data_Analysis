# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Problem Statement / Objective

# %% [markdown]
# The objective of this analysis is to gain insights into the characteristics of colleges and answer key questions related to the educational landscape. By understanding the data, we aim to inform strategies for improving the quality of education and enhancing the overall college experience. The analysis will provide valuable insights and recommendations for stakeholders in the education sector.

# %% [markdown]
# # Data Description
#
# •	Names: Names of various university and colleges
#
# •	Apps: Number of applications received
#
# •	Accept: Number of applications accepted
#
# •	Enroll: Number of new students enrolled
#
# •	Top10perc: Percentage of new students from top 10% of Higher Secondary class
#
# •	Top25perc: Percentage of new students from top 25% of Higher Secondary class
#
# •	F.Undergrad: Number of full-time undergraduate students
#
# •	P.Undergrad: Number of part-time undergraduate students
#
# •	Outstate: Number of students for whom the particular college or university is Out-of-state tuition
#
# •	Room.Board: Cost of Room and board
#
# •	Books: Estimated book costs for a student
#
# •	Personal: Estimated personal spending for a student
#
# •	PhD: Percentage of faculties with Ph.D.’s
#
# •	Terminal: Percentage of faculties with terminal degree
#
# •	S.F.Ratio: Student/faculty ratio
#
# •	perc.alumni: Percentage of alumni who donate
#
# •	Expend: The Instructional expenditure per student
#
# •	Grad.Rate: Graduation rate

# %% [markdown]
# # Basic Steps

# %% [markdown]
# 1-	Display the top 5 rows.
#
# 2-	Display the last 5 rows.
#
# 3-	Check the shape of dataset.
#
# 4-	Check the datatypes of each feature.
#
# 5-	Check the Statistical summary.
#
# 6-	Check the null values.
#
# 7-	Check the duplicate values.
#
# 8-	Check the anomalies or wrong entries.
#
# 9-	Check the outliers and their authenticity.
#
# 10-	Do the necessary data cleaning steps like dropping duplicates, unnecessary columns, null value imputation, outliers treatment etc.

# %% [markdown]
# # Importing the necessary Libraries

# %% [markdown]
# Importing libraries such as:
# 1. Pandas
# 2. Numpy
# 3. Matplotlib.pyplot
# 4. Seaborn

# %% [markdown]
# # Loading the dataset

# %% [markdown]
# Loading the required dataset,i.e., Education_Post_12th_Standard_Data.csv

# %% [markdown]
# # 1- Display the top 5 rows

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Observation:

# %% [markdown]
# There is a wrong entry in S.F.Ratio (Student/faculty ratio) column for Adelphi University.

# %% [markdown]
# # 2- Display the last 5 rows

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 3- Check the shape and information of the dataset

# %% [markdown]
# Shape of the dataset: (777, 18)

# %% [markdown]
# Information about the dataset

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Observation

# %% [markdown]
# 1. The Datatype of S.F.Ratio is object.
# 2. S.F.Ratio also contains wrong entries,i.e.,"?".

# %% [markdown]
#  # 4- Check the datatypes of each feature

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 5- Check the statistical summary

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Observation

# %% [markdown]
# 1. Minimun Estimated book costs for a student is 0
# 2. Minimum Percentage of alumni who donate is 0
# 3. Maximum Graduation rate is 118

# %% [markdown]
# # 6- Check the null values

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Observation

# %% [markdown]
# There are 4 columns that contains NULL values
#
# •	Apps: Number of applications received (2 NULL values)
#
# •	Enroll: Number of new students enrolled (2 NULL values)
#
# •	Top10perc: Percentage of new students from top 10% of Higher Secondary class(4 NULL values)
#
# •	Personal: Estimated personal spending for a student(3 NULL values)

# %% [markdown]
# # 7- Check the duplicate values

# %% [markdown]
# # Observation

# %% [markdown]
# No duplicate values are present

# %% [markdown]
# # 8- Check the outliers and their authenticity

# %% [markdown]
# ![output.png](attachment:output.png)

# %% [markdown]
# # Observation

# %% [markdown]
# F.Undergrad column contains the max number of outliers

# %% [markdown]
# # 9-	Check the outliers and their authenticity.

# %% [markdown]
# There are some wrong entries in S.F.Ratio (Student/faculty ratio) column for Adelphi University

# %% [markdown]
# # 10-	Do the necessary data cleaning steps like dropping duplicates, unnecessary columns, null value imputation, outliers treatment etc.

# %% [markdown]
# # Dropping Duplicates
# No duplicates are there in data

# %% [markdown]
# # Outliers Treatment

# %% [markdown]
# ![output2.png](attachment:output2.png)

# %% [markdown]
# # Null value imputation

# %% [markdown]
# ![Screenshot%202024-06-20%20100400.png](attachment:Screenshot%202024-06-20%20100400.png)

# %% [markdown]
# 1. Treating null values of column ((Apps) -> Number of applications received column) with the  help of its mean value (3007.592258064516).
# 2.  Treating null values of column ((Enroll) -> Number of applications received) with the  help of its mean value (780.9612903225807).
# 3. Treating null values of column ((Top10perc) -> Percentage of new students from top 10% of Higher Secondary class) with the  help of its mean value (27.620957309184995).
# 4. Treating null values of column ((Personal) -> Estimated personal spending for a student) with the  help of its mean value (1601.5077519379845)

# %% [markdown]
# 1. Change the datatype of S.F.Ratio from object to float
# 2. Replacing the wrong entries with nan
# 3. Replacing the nan values with the mean value of ((S.F.Ratio) -> Student/faculty ratio) column,i.e, 14.09031007751938.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Application and Enrollment Analysis

# %% [markdown]
# 1. What is the average number of applications received by colleges?

# %% [markdown]
# applications_mean: 2578.4090322580646

# %% [markdown]
# 2. What percentage of applications are accepted on average across all colleges?

# %% [markdown]
# accepted_applications_percentage: 67.72705743864252

# %% [markdown]
# 3. What is the average enrollment rate (number of students enrolled divided by number of applications accepted)?

# %% [markdown]
# enrollment_rate: 0.3785871340519121

# %% [markdown]
# 4. Which college has the highest number of applications received?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Academic Excellence

# %% [markdown]
# 1. What is the average percentage of new students from the top 10% of their higher secondary class across all colleges?

# %% [markdown]
# avg_top_10_percentage: 27.620957309184995

# %% [markdown]
# 2. What is the average percentage of new students from the top 25% of their higher secondary class?

# %% [markdown]
# avg_top_25_percentage: 55.7966537966538

# %% [markdown]
# 3. Is there a correlation between the percentage of students from the top 10% and the top 25% of their higher secondary class?

# %% [markdown]
# correlation: 0.8916010734346559

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Student Demographics

# %% [markdown]
# 1. What is the average number of full-time undergraduate students per college?

# %% [markdown]
# full_time_undergraduate_students_mean: 3699.907335907336

# %% [markdown]
# 2. What is the average number of part-time undergraduate students per college?

# %% [markdown]
# part_time_undergraduate_students_mean: 855.2985842985843

# %% [markdown]
# 3. Which college has the highest number of out-of-state students?

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Cost and Spending

# %% [markdown]
# 1. What is the average cost of room and board across all colleges?

# %% [markdown]
# room_board_mean: 4357.526383526383

# %% [markdown]
# 2. What is the average estimated book cost for a student?

# %% [markdown]
# book_cost_mean: 547.8751608751609

# %% [markdown]
# 3. What is the average estimated personal spending for a student?

# %% [markdown]
# personal_spending_mean: 1601.5077519379845

# %% [markdown]
# 4. How does the instructional expenditure per student vary across colleges?

# %% [markdown]
# instructional_expenditure_mean: 9660.17117117117

# %% [markdown]
# # Faculty Qualifications

# %% [markdown]
# 1. What is the average percentage of faculties with Ph.D.s across all colleges?

# %% [markdown]
# phd_percentage_mean: 72.66023166023166

# %% [markdown]
# 2. What is the average percentage of faculties with terminal degrees?

# %% [markdown]
# terminal_percentage_mean: 79.70270270270271

# %% [markdown]
# 3. Is there a correlation between the percentage of faculties with Ph.D.s and the graduation rate?

# %% [markdown]
# correlation: 0.30503785002341177

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Student-Faculty Interaction

# %% [markdown]
# 1. What is the average student/faculty ratio across all colleges?

# %% [markdown]
# student_faculty_ratio_mean: 14.09031007751938

# %% [markdown]
# 2. Which college has the lowest student/faculty ratio?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 3. Is there a correlation between the student/faculty ratio and the graduation rate?

# %% [markdown]
# correlation: -0.3050214357418167

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Alumni Engagement

# %% [markdown]
# 1. What is the average percentage of alumni who donate across all colleges?

# %% [markdown]
# alumni_donate_mean: 22.743886743886744

# %% [markdown]
# 2. Is there a correlation between the percentage of alumni who donate and the graduation rate?

# %% [markdown]
# correlation: 0.49089756228472003

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Graduation Rates

# %% [markdown]
# 1. What is the average graduation rate across all colleges?

# %% [markdown]
# graduation_rate_mean: 65.46332046332046

# %% [markdown]
# 2. Which college has the highest graduation rate?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 3. Is there a correlation between the instructional expenditure per student and the graduation rate?

# %% [markdown]
# correlation: 0.39034269585938924

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Overall Insights

# %% [markdown]
# 1. What recommendations can be made to colleges to improve their graduation rates based on the data analysis?

# %% [markdown]
#  Based on the data analysis, the following recommendations can be made to colleges to improve their graduation rates:
#
#  1. Focus on improving the academic preparation of students entering college.
#  2. Provide more support to students during their first year of college.
#  3. Create a more positive and supportive campus environment.
#  4. Make sure that students have access to affordable housing and food.
#  5. Regularly evaluate and update graduation rates.
#  6. Share best practices with other colleges and universities.
